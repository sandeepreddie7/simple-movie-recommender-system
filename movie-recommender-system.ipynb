# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/imdb-csv/IMDB-Movie-Data.csv

# %%
df = pd.read_csv('../input/imdb-csv/IMDB-Movie-Data.csv')
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # TOP 10 MOVIES BASED ON REVENUE

# %%
df[['Revenue (Millions)', 'Title']].sort_values(by = 'Revenue (Millions)', ascending=False).head(10)
# Out:
#      Revenue (Millions)                                       Title
# 50               936.63  Star Wars: Episode VII - The Force Awakens
# 87               760.51                                      Avatar
# 85               652.18                              Jurassic World
# 76               623.28                                The Avengers
# 54               533.32                             The Dark Knight
# 12               532.17                                   Rogue One
# 119              486.29                                Finding Dory
# 94               458.99                     Avengers: Age of Ultron
# 124              448.13                       The Dark Knight Rises
# 578              424.65             The Hunger Games: Catching Fire

# %% [markdown]
# # TOP 10 BEST MOVIES BASED ON IMDb RATING

# %%
df[['Rating', 'Title']].sort_values(by = 'Rating', ascending=False).head(10)
# Out:
#      Rating             Title
# 54      9.0   The Dark Knight
# 80      8.8         Inception
# 117     8.8            Dangal
# 36      8.6      Interstellar
# 96      8.6     Kimi no na wa
# 249     8.6  The Intouchables
# 133     8.5          Whiplash
# 64      8.5      The Prestige
# 99      8.5      The Departed
# 991     8.5  Taare Zameen Par

# %% [markdown]
# # TOP 10 BEST MOVIES BASED ON METASCORE

# %%
df[['Metascore', 'Title']].sort_values(by = 'Metascore', ascending=False).head(10)
# Out:
#      Metascore                  Title
# 656      100.0                Boyhood
# 41        99.0              Moonlight
# 230       98.0        Pan's Labyrinth
# 111       96.0       12 Years a Slave
# 509       96.0                Gravity
# 489       96.0            Ratatouille
# 21        96.0  Manchester by the Sea
# 501       95.0                  Carol
# 406       95.0       Zero Dark Thirty
# 324       95.0     The Social Network

# %% [markdown]
# # SHORT IS SWEET, TOP 10 SHORTEST MOVIES

# %%
df[['Runtime (Minutes)', 'Title']].sort_values(by = 'Runtime (Minutes)', ascending=True).head(10)
# Out:
#      Runtime (Minutes)                                              Title
# 793                 66                                Ma vie de Courgette
# 42                  73                            Don't Fuck in the Woods
# 819                 73                                 Wolves at the Door
# 711                 80                                    La tortue rouge
# 949                 80                                              Kicks
# 258                 81                                         Lights Out
# 317                 81                                    The Stakelander
# 862                 81  Alexander and the Terrible, Horrible, No Good,...
# 382                 81                                               Hush
# 444                 81                                       The Thinning

# %% [markdown]
# # PASS MORE TIME, TOP 10 LONGEST MOVIES

# %%
df[['Runtime (Minutes)', 'Title']].sort_values(by = 'Runtime (Minutes)', ascending=False).head(10)
# Out:
#      Runtime (Minutes)                                     Title
# 828                191                                Grindhouse
# 88                 187                         The Hateful Eight
# 965                180                             Inland Empire
# 311                180                            La vie d'Adèle
# 82                 180                   The Wolf of Wall Street
# 267                172                               Cloud Atlas
# 430                170                                  3 Idiots
# 75                 169  Pirates of the Caribbean: At World's End
# 271                169         The Hobbit: An Unexpected Journey
# 36                 169                              Interstellar
